# %%
pip install pandas matplotlib seaborn plotly
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd

data = {
    "Date": ["2024-01-01", "2024-01-02", "2024-01-03", "2024-01-04", "2024-01-05", "2024-01-06"],
    "Product": ["A", "B", "C", "D", "E", "F"],
    "Category": ["Electronics", "Electronics", "Fashion", "Fashion", "Groceries", "Groceries"],
    "Sales": [200, 300, 150, 180, 100, 120],
    "Profit": [50, 80, 40, 30, 10, 15]
}

df = pd.DataFrame(data)
df.to_csv("sales.csv", index=False)

# %%
import pandas as pd

df = pd.read_csv("sales.csv")
print(df.head())
# Out:
#          Date Product     Category  Sales  Profit
# 0  2024-01-01       A  Electronics    200      50
# 1  2024-01-02       B  Electronics    300      80
# 2  2024-01-03       C      Fashion    150      40
# 3  2024-01-04       D      Fashion    180      30
# 4  2024-01-05       E    Groceries    100      10

# %%
print(df.info())
print(df.describe())
print(df['Category'].value_counts())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Date      6 non-null      object
#  1   Product   6 non-null      object
#  2   Category  6 non-null      object
#  3   Sales     6 non-null      int64
#  4   Profit    6 non-null      int64
# dtypes: int64(2), object(3)
# memory usage: 372.0+ bytes
# None
#             Sales     Profit
# count    6.000000   6.000000
# mean   175.000000  37.500000
# std     71.484264  25.641763
# min    100.000000  10.000000
# 25%    127.500000  18.750000
# 50%    165.000000  35.000000
# 75%    195.000000  47.500000
# max    300.000000  80.000000
# Category
# Electronics    2
# Fashion        2
# Groceries      2
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
category_sales = df.groupby('Category')['Sales'].sum().reset_index()
sns.barplot(data=category_sales, x='Category', y='Sales')
plt.title("Total Sales by Category")
plt.show()

# %%
df['Date'] = pd.to_datetime(df['Date'])
plt.plot(df['Date'], df['Sales'], marker='o')
plt.title("Sales Over Time")
plt.xlabel("Date")
plt.ylabel("Sales")
plt.grid(True)
plt.show()

# %%
sns.scatterplot(data=df, x='Sales', y='Profit', hue='Category')
plt.title("Sales vs Profit")
plt.show()

# %%
category_sales.set_index('Category')['Sales'].plot.pie(autopct='%1.1f%%')
plt.title("Sales Share by Category")
plt.ylabel("")
plt.show()

# %%
plt.figure()
sns.barplot(data=category_sales, x='Category', y='Sales')
plt.title("Total Sales by Category")
plt.savefig("sales_by_category.png")
